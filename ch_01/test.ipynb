# %%
# below methods are studied...
# json.dump(plot_data, fp, ensure_ascii=False, indent=2)
# path.as_posix()
# OUT_2_4.is_file()
# base_dir.glob(pattern="**/*.txt")
# base_dir.iterdir()
# fullpath.stat().st_size
